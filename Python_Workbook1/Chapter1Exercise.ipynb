# %% [markdown]
# **Exercise 1:**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
Print('Hello world!')

#The P in print is in captital letter.
# Out:
# Hello world!

# %%
print('Hello world!')
#print('Hello world!)
#theres no apostrophe after the exclamation mark
# Out:
# Hello world!

# %%
print('Hello world!')

#print('Hello world!)
#there are no open parenthesis
# Out:
# Hello world!

# %%
print('Hello world!')
#print('Hello world!'')
#the exlamation apostrophe after the exclamation mark is double
# Out:
# Hello world!

# %% [markdown]
# **Exercise 2:**

# %%
x = 43
x = x + 1
print(x)

#The output is 43 because the value of x is 43.

# %% [markdown]
# **Exercise 3:**

# %%
x = 43
x = X + 1
print(x)


#x = X + 1


# The x must be in small letter not in capital
# Out:
# 44
